# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# 0 - akiec
# 1 - bcc
# 2 - bkl
# 3 - df
# 4 - nv
# 5 - vasc
# 6 - mel

# %%
# !mkdir "Data"
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/* /kaggle/working/Data
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/* /kaggle/working/Data

# %%
data = pd.read_csv("/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv")
data
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
data = data.drop(["lesion_id", "dx_type", "age", "localization", "sex"], axis=1)
data
# Out:
#            image_id     dx
# 0      ISIC_0027419    bkl
# 1      ISIC_0025030    bkl
# 2      ISIC_0026769    bkl
# 3      ISIC_0025661    bkl
# 4      ISIC_0031633    bkl
# ...             ...    ...
# 10010  ISIC_0033084  akiec
# 10011  ISIC_0033550  akiec
# 10012  ISIC_0033536  akiec
# 10013  ISIC_0032854  akiec
# 10014  ISIC_0032258    mel
#
# [10015 rows x 2 columns]

# %%
data["dx"].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
# data["label"] = [labels[x] for x in data["dx"]]
# data

# %% [markdown]
# # Preprocessing the Images

# %%
dataPath = Path(r"/kaggle/working/Data")
print(len(os.listdir(dataPath)))
# Out:
# 10015

# %%
data["image_id"] = [f"{dataPath}/{x}.jpg" for x in data["image_id"]]
data
# Out:
#                                     image_id     dx
# 0      /kaggle/working/Data/ISIC_0027419.jpg    bkl
# 1      /kaggle/working/Data/ISIC_0025030.jpg    bkl
# 2      /kaggle/working/Data/ISIC_0026769.jpg    bkl
# 3      /kaggle/working/Data/ISIC_0025661.jpg    bkl
# 4      /kaggle/working/Data/ISIC_0031633.jpg    bkl
# ...                                      ...    ...
# 10010  /kaggle/working/Data/ISIC_0033084.jpg  akiec
# 10011  /kaggle/working/Data/ISIC_0033550.jpg  akiec
# 10012  /kaggle/working/Data/ISIC_0033536.jpg  akiec
# 10013  /kaggle/working/Data/ISIC_0032854.jpg  akiec
# 10014  /kaggle/working/Data/ISIC_0032258.jpg    mel
#
# [10015 rows x 2 columns]

# %%
train_data, test_data = train_test_split(data, test_size=.2, stratify=data.dx)
train_data, valid_data = train_test_split(data, test_size=.2, stratify=data.dx)

# %%
train_data.shape, valid_data.shape, test_data.shape
# Out:
# ((8012, 2), (2003, 2), (2003, 2))

# %%
imageDataGenerator = ImageDataGenerator(rescale=1/255.)
train_gen = imageDataGenerator.flow_from_dataframe(train_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
valid_gen = imageDataGenerator.flow_from_dataframe(valid_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
test_gen = imageDataGenerator.flow_from_dataframe(test_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
# Out:
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.

# %%
labels = train_gen.class_indices
labels
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
model = Sequential([
    layers.Input(shape=[224, 224, 3], name="Inputs"),
    layers.Conv2D(16, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool1"),
    layers.BatchNormalization(name="BatchNorm1"),
    layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool2"),
    layers.BatchNormalization(name="BatchNorm2"),
    layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool3"),
    layers.BatchNormalization(name="BatchNorm3"),
    layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool4"),
    layers.BatchNormalization(name="BatchNorm4"),
    layers.Flatten(name="Flatten"),
    layers.Dense(7, activation="softmax", name="Outputs")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv2D)              (None, 224, 224, 16)      448
#
#  maxpool1 (MaxPooling2D)     (None, 112, 112, 16)      0
#
#  BatchNorm1 (BatchNormalizat  (None, 112, 112, 16)     64
#  ion)
#
#  Conv2 (Conv2D)              (None, 112, 112, 32)      4640
#
#  maxpool2 (MaxPooling2D)     (None, 56, 56, 32)        0
#
#  BatchNorm2 (BatchNormalizat  (None, 56, 56, 32)       128
#  ion)
#
#  Conv3 (Conv2D)              (None, 56, 56, 64)        18496
#
#  maxpool3 (MaxPooling2D)     (None, 28, 28, 64)        0
#
#  BatchNorm3 (BatchNormalizat  (None, 28, 28, 64)       256
#  ion)
#
#  Conv4 (Conv2D)              (None, 28, 28, 128)       73856
#
#  maxpool4 (MaxPooling2D)     (None, 14, 14, 128)       0
#
#  BatchNorm4 (BatchNormalizat  (None, 14, 14, 128)      512
#  ion)
#
#  Flatten (Flatten)           (None, 25088)             0
#
#  Outputs (Dense)             (None, 7)                 175623
#
# =================================================================
# Total params: 274,023
# Trainable params: 273,543
# Non-trainable params: 480
# _________________________________________________________________

# %%
plot_model(model, show_layer_names=True, show_shapes=True)

# %%
def learningRate(epoch, lr):
    if epoch >= 30:
        return lr * .9
    return lr

learningRateScheduler = LearningRateScheduler(learningRate)

# %%
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=1e-4), metrics=['accuracy'])

# %%
history = model.fit(train_gen, validation_data=valid_gen, epochs=50, callbacks=[learningRateScheduler])
# Out:
# Epoch 1/50
# 501/501 [==============================] - 93s 149ms/step - loss: 0.9896 - accuracy: 0.6796 - val_loss: 1.0899 - val_accuracy: 0.5996 - lr: 1.0000e-04
# Epoch 2/50
# 501/501 [==============================] - 69s 138ms/step - loss: 0.6989 - accuracy: 0.7559 - val_loss: 0.8344 - val_accuracy: 0.6985 - lr: 1.0000e-04
# Epoch 3/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.5547 - accuracy: 0.8027 - val_loss: 0.7846 - val_accuracy: 0.7389 - lr: 1.0000e-04
# Epoch 4/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.4419 - accuracy: 0.8365 - val_loss: 0.8316 - val_accuracy: 0.7424 - lr: 1.0000e-04
# Epoch 5/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.3318 - accuracy: 0.8824 - val_loss: 0.8289 - val_accuracy: 0.7509 - lr: 1.0000e-04
# Epoch 6/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.2680 - accuracy: 0.9048 - val_loss: 0.8433 - val_accuracy: 0.7359 - lr: 1.0000e-04
# Epoch 7/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.2056 - accuracy: 0.9317 - val_loss: 0.8484 - val_accuracy: 0.7504 - lr: 1.0000e-04
# Epoch 8/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.1708 - accuracy: 0.9432 - val_loss: 0.8905 - val_accuracy: 0.7344 - lr: 1.0000e-04
# Epoch 9/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.1269 - accuracy: 0.9581 - val_loss: 0.8957 - val_accuracy: 0.7209 - lr: 1.0000e-04
# Epoch 10/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.0918 - accuracy: 0.9760 - val_loss: 0.9811 - val_accuracy: 0.7479 - lr: 1.0000e-04
# Epoch 11/50
# 501/501 [==============================] - 68s 136ms/step - loss: 0.0658 - accuracy: 0.9844 - val_loss: 0.9755 - val_accuracy: 0.7499 - lr: 1.0000e-04
# Epoch 12/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.0532 - accuracy: 0.9871 - val_loss: 1.0110 - val_accuracy: 0.7264 - lr: 1.0000e-04
# Epoch 13/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.0566 - accuracy: 0.9841 - val_loss: 1.0183 - val_accuracy: 0.7444 - lr: 1.0000e-04
# Epoch 14/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.0462 - accuracy: 0.9894 - val_loss: 1.0394 - val_accuracy: 0.7514 - lr: 1.0000e-04
# Epoch 15/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.0298 - accuracy: 0.9951 - val_loss: 1.0493 - val_accuracy: 0.7514 - lr: 1.0000e-04
# Epoch 16/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.0401 - accuracy: 0.9890 - val_loss: 1.1446 - val_accuracy: 0.7184 - lr: 1.0000e-04
# Epoch 17/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.0418 - accuracy: 0.9879 - val_loss: 1.2010 - val_accuracy: 0.7344 - lr: 1.0000e-04
# Epoch 18/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.0238 - accuracy: 0.9953 - val_loss: 1.1927 - val_accuracy: 0.7479 - lr: 1.0000e-04
# Epoch 19/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.0277 - accuracy: 0.9929 - val_loss: 1.2691 - val_accuracy: 0.7344 - lr: 1.0000e-04
# Epoch 20/50
# 501/501 [==============================] - 66s 131ms/step - loss: 0.0381 - accuracy: 0.9893 - val_loss: 1.2274 - val_accuracy: 0.7319 - lr: 1.0000e-04
# Epoch 21/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.0189 - accuracy: 0.9958 - val_loss: 1.2365 - val_accuracy: 0.7369 - lr: 1.0000e-04
# Epoch 22/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.0175 - accuracy: 0.9955 - val_loss: 1.2595 - val_accuracy: 0.7469 - lr: 1.0000e-04
# Epoch 23/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.0089 - accuracy: 0.9989 - val_loss: 1.2690 - val_accuracy: 0.7429 - lr: 1.0000e-04
# Epoch 24/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 1.3447 - val_accuracy: 0.7449 - lr: 1.0000e-04
# Epoch 25/50
# 501/501 [==============================] - 66s 131ms/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 1.5227 - val_accuracy: 0.7209 - lr: 1.0000e-04
# Epoch 26/50
# 501/501 [==============================] - 66s 131ms/step - loss: 0.0442 - accuracy: 0.9849 - val_loss: 1.4159 - val_accuracy: 0.7449 - lr: 1.0000e-04
# Epoch 27/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.0176 - accuracy: 0.9955 - val_loss: 1.4100 - val_accuracy: 0.7439 - lr: 1.0000e-04
# Epoch 28/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.0048 - accuracy: 0.9995 - val_loss: 1.4024 - val_accuracy: 0.7464 - lr: 1.0000e-04
# Epoch 29/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 1.3549 - val_accuracy: 0.7489 - lr: 1.0000e-04
# Epoch 30/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 1.4557 - val_accuracy: 0.7274 - lr: 1.0000e-04
# Epoch 31/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.0390 - accuracy: 0.9880 - val_loss: 1.4092 - val_accuracy: 0.7399 - lr: 9.0000e-05
# Epoch 32/50
# 501/501 [==============================] - 68s 136ms/step - loss: 0.0098 - accuracy: 0.9980 - val_loss: 1.4112 - val_accuracy: 0.7419 - lr: 8.1000e-05
# Epoch 33/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.0026 - accuracy: 0.9999 - val_loss: 1.4165 - val_accuracy: 0.7424 - lr: 7.2900e-05
# Epoch 34/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4253 - val_accuracy: 0.7459 - lr: 6.5610e-05
# Epoch 35/50
# 501/501 [==============================] - 74s 148ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 1.4542 - val_accuracy: 0.7449 - lr: 5.9049e-05
# Epoch 36/50
# 501/501 [==============================] - 65s 129ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 1.4728 - val_accuracy: 0.7514 - lr: 5.3144e-05
# Epoch 37/50
# 501/501 [==============================] - 66s 133ms/step - loss: 7.9519e-04 - accuracy: 1.0000 - val_loss: 1.4380 - val_accuracy: 0.7479 - lr: 4.7830e-05
# Epoch 38/50
# 501/501 [==============================] - 68s 135ms/step - loss: 9.1647e-04 - accuracy: 1.0000 - val_loss: 1.4522 - val_accuracy: 0.7514 - lr: 4.3047e-05
# Epoch 39/50
# 501/501 [==============================] - 66s 132ms/step - loss: 8.0710e-04 - accuracy: 1.0000 - val_loss: 1.4787 - val_accuracy: 0.7469 - lr: 3.8742e-05
# Epoch 40/50
# 501/501 [==============================] - 67s 133ms/step - loss: 7.3961e-04 - accuracy: 1.0000 - val_loss: 1.4586 - val_accuracy: 0.7429 - lr: 3.4868e-05
# Epoch 41/50
# 501/501 [==============================] - 66s 131ms/step - loss: 6.4413e-04 - accuracy: 1.0000 - val_loss: 1.4482 - val_accuracy: 0.7529 - lr: 3.1381e-05
# Epoch 42/50
# 501/501 [==============================] - 65s 130ms/step - loss: 5.7324e-04 - accuracy: 1.0000 - val_loss: 1.4476 - val_accuracy: 0.7509 - lr: 2.8243e-05
# Epoch 43/50
# 501/501 [==============================] - 74s 147ms/step - loss: 5.3446e-04 - accuracy: 1.0000 - val_loss: 1.4581 - val_accuracy: 0.7489 - lr: 2.5419e-05
# Epoch 44/50
# 501/501 [==============================] - 66s 132ms/step - loss: 6.2289e-04 - accuracy: 1.0000 - val_loss: 1.4461 - val_accuracy: 0.7489 - lr: 2.2877e-05
# Epoch 45/50
# 501/501 [==============================] - 67s 133ms/step - loss: 5.9935e-04 - accuracy: 1.0000 - val_loss: 1.4696 - val_accuracy: 0.7489 - lr: 2.0589e-05
# Epoch 46/50
# 501/501 [==============================] - 67s 133ms/step - loss: 4.4810e-04 - accuracy: 1.0000 - val_loss: 1.4911 - val_accuracy: 0.7549 - lr: 1.8530e-05
# Epoch 47/50
# 501/501 [==============================] - 66s 131ms/step - loss: 6.7537e-04 - accuracy: 1.0000 - val_loss: 1.4620 - val_accuracy: 0.7484 - lr: 1.6677e-05
# Epoch 48/50
# 501/501 [==============================] - 65s 130ms/step - loss: 4.2516e-04 - accuracy: 1.0000 - val_loss: 1.4682 - val_accuracy: 0.7539 - lr: 1.5009e-05
# Epoch 49/50
# 501/501 [==============================] - 67s 133ms/step - loss: 2.6990e-04 - accuracy: 1.0000 - val_loss: 1.4981 - val_accuracy: 0.7524 - lr: 1.3509e-05
# Epoch 50/50
# 501/501 [==============================] - 66s 131ms/step - loss: 5.4188e-04 - accuracy: 1.0000 - val_loss: 1.4716 - val_accuracy: 0.7544 - lr: 1.2158e-05

# %%
loss, acc = model.evaluate(test_gen)
# Out:
# 126/126 [==============================] - 13s 100ms/step - loss: 0.2946 - accuracy: 0.9516

# %%
model.save("Attempt-4.h5")

# %%
metrics = ["accuracy", "loss"]
for metric in metrics:
    print(metric.upper())
    mt = history.history[metric]
    rng = [x for x in range(1, len(mt)+1)]
    vmt = history.history[v := "val_"+metric]
    plt.plot(rng, mt, label=metric.upper())
    plt.plot(rng, vmt, label=v.upper())
    plt.ylim(*(0, 1) if metric != "loss" else  (0, 5))
    plt.legend()
    plt.show()
# Out:
# ACCURACY
# LOSS
