# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# 0 - akiec
# 1 - bcc
# 2 - bkl
# 3 - df
# 4 - nv
# 5 - vasc
# 6 - mel

# %%
# !mkdir "Data"
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/* /kaggle/working/Data
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/* /kaggle/working/Data

# %%
data = pd.read_csv("/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv")
data
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
data = data.drop(["lesion_id", "dx_type", "age", "localization", "sex"], axis=1)
data
# Out:
#            image_id     dx
# 0      ISIC_0027419    bkl
# 1      ISIC_0025030    bkl
# 2      ISIC_0026769    bkl
# 3      ISIC_0025661    bkl
# 4      ISIC_0031633    bkl
# ...             ...    ...
# 10010  ISIC_0033084  akiec
# 10011  ISIC_0033550  akiec
# 10012  ISIC_0033536  akiec
# 10013  ISIC_0032854  akiec
# 10014  ISIC_0032258    mel
#
# [10015 rows x 2 columns]

# %%
data["dx"].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
# data["label"] = [labels[x] for x in data["dx"]]
# data

# %% [markdown]
# # Preprocessing the Images

# %%
dataPath = Path(r"/kaggle/working/Data")
print(len(os.listdir(dataPath)))
# Out:
# 10015

# %%
data["image_id"] = [f"{dataPath}/{x}.jpg" for x in data["image_id"]]
data
# Out:
#                                     image_id     dx
# 0      /kaggle/working/Data/ISIC_0027419.jpg    bkl
# 1      /kaggle/working/Data/ISIC_0025030.jpg    bkl
# 2      /kaggle/working/Data/ISIC_0026769.jpg    bkl
# 3      /kaggle/working/Data/ISIC_0025661.jpg    bkl
# 4      /kaggle/working/Data/ISIC_0031633.jpg    bkl
# ...                                      ...    ...
# 10010  /kaggle/working/Data/ISIC_0033084.jpg  akiec
# 10011  /kaggle/working/Data/ISIC_0033550.jpg  akiec
# 10012  /kaggle/working/Data/ISIC_0033536.jpg  akiec
# 10013  /kaggle/working/Data/ISIC_0032854.jpg  akiec
# 10014  /kaggle/working/Data/ISIC_0032258.jpg    mel
#
# [10015 rows x 2 columns]

# %%
train_data, test_data = train_test_split(data, test_size=.2, stratify=data.dx)
train_data, valid_data = train_test_split(data, test_size=.2, stratify=data.dx)

# %%
train_data.shape, valid_data.shape, test_data.shape
# Out:
# ((8012, 2), (2003, 2), (2003, 2))

# %%
imageDataGenerator = ImageDataGenerator(rescale=1/255.)
train_gen = imageDataGenerator.flow_from_dataframe(train_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
valid_gen = imageDataGenerator.flow_from_dataframe(valid_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
test_gen = imageDataGenerator.flow_from_dataframe(test_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
# Out:
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.

# %%
labels = train_gen.class_indices
labels
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
model = Sequential([
    layers.Input(shape=[224, 224, 3], name="Inputs"),
    layers.Conv2D(16, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool1"),
    layers.BatchNormalization(name="BatchNorm1"),
    layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool2"),
    layers.BatchNormalization(name="BatchNorm2"),
    layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool3"),
    layers.BatchNormalization(name="BatchNorm3"),
    layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool4"),
    layers.BatchNormalization(name="BatchNorm4"),
    layers.GlobalAveragePooling2D(name="GAP"),
    layers.Dense(7, activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv2D)              (None, 224, 224, 16)      448
#
#  maxpool1 (MaxPooling2D)     (None, 112, 112, 16)      0
#
#  BatchNorm1 (BatchNormalizat  (None, 112, 112, 16)     64
#  ion)
#
#  Conv2 (Conv2D)              (None, 112, 112, 32)      4640
#
#  maxpool2 (MaxPooling2D)     (None, 56, 56, 32)        0
#
#  BatchNorm2 (BatchNormalizat  (None, 56, 56, 32)       128
#  ion)
#
#  Conv3 (Conv2D)              (None, 56, 56, 64)        18496
#
#  maxpool3 (MaxPooling2D)     (None, 28, 28, 64)        0
#
#  BatchNorm3 (BatchNormalizat  (None, 28, 28, 64)       256
#  ion)
#
#  Conv4 (Conv2D)              (None, 28, 28, 128)       73856
#
#  maxpool4 (MaxPooling2D)     (None, 14, 14, 128)       0
#
#  BatchNorm4 (BatchNormalizat  (None, 14, 14, 128)      512
#  ion)
#
#  GAP (GlobalAveragePooling2D  (None, 128)              0
#  )
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 99,303
# Trainable params: 98,823
# Non-trainable params: 480
# _________________________________________________________________

# %%
plot_model(model, show_layer_names=True, show_shapes=True)

# %%
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=1e-4), metrics=['accuracy'])

# %%
history = model.fit(train_gen, validation_data=valid_gen, epochs=50)
# Out:
# Epoch 1/50
# 501/501 [==============================] - 73s 139ms/step - loss: 1.4964 - accuracy: 0.5638 - val_loss: 1.0541 - val_accuracy: 0.6780
# Epoch 2/50
# 501/501 [==============================] - 68s 136ms/step - loss: 1.1563 - accuracy: 0.6505 - val_loss: 1.0540 - val_accuracy: 0.6805
# Epoch 3/50
# 501/501 [==============================] - 69s 138ms/step - loss: 0.9522 - accuracy: 0.6933 - val_loss: 0.9574 - val_accuracy: 0.6835
# Epoch 4/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.8488 - accuracy: 0.7053 - val_loss: 0.8317 - val_accuracy: 0.7069
# Epoch 5/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.7992 - accuracy: 0.7208 - val_loss: 0.7973 - val_accuracy: 0.7104
# Epoch 6/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.7796 - accuracy: 0.7203 - val_loss: 0.7605 - val_accuracy: 0.7324
# Epoch 7/50
# 501/501 [==============================] - 68s 136ms/step - loss: 0.7658 - accuracy: 0.7203 - val_loss: 0.7590 - val_accuracy: 0.7249
# Epoch 8/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.7546 - accuracy: 0.7254 - val_loss: 0.7759 - val_accuracy: 0.7269
# Epoch 9/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.7391 - accuracy: 0.7322 - val_loss: 0.7937 - val_accuracy: 0.7214
# Epoch 10/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.7256 - accuracy: 0.7344 - val_loss: 0.7851 - val_accuracy: 0.7244
# Epoch 11/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.7202 - accuracy: 0.7371 - val_loss: 0.7962 - val_accuracy: 0.7174
# Epoch 12/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.7062 - accuracy: 0.7403 - val_loss: 0.7142 - val_accuracy: 0.7484
# Epoch 13/50
# 501/501 [==============================] - 66s 131ms/step - loss: 0.7039 - accuracy: 0.7420 - val_loss: 0.7212 - val_accuracy: 0.7374
# Epoch 14/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.6921 - accuracy: 0.7460 - val_loss: 0.7350 - val_accuracy: 0.7419
# Epoch 15/50
# 501/501 [==============================] - 68s 136ms/step - loss: 0.6882 - accuracy: 0.7479 - val_loss: 0.8791 - val_accuracy: 0.6985
# Epoch 16/50
# 501/501 [==============================] - 68s 136ms/step - loss: 0.6862 - accuracy: 0.7448 - val_loss: 0.6937 - val_accuracy: 0.7464
# Epoch 17/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.6764 - accuracy: 0.7507 - val_loss: 0.6900 - val_accuracy: 0.7574
# Epoch 18/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.6721 - accuracy: 0.7532 - val_loss: 0.6810 - val_accuracy: 0.7629
# Epoch 19/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.6598 - accuracy: 0.7544 - val_loss: 0.7168 - val_accuracy: 0.7514
# Epoch 20/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.6600 - accuracy: 0.7557 - val_loss: 0.6811 - val_accuracy: 0.7584
# Epoch 21/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.6560 - accuracy: 0.7555 - val_loss: 0.8501 - val_accuracy: 0.7019
# Epoch 22/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.6448 - accuracy: 0.7626 - val_loss: 0.7003 - val_accuracy: 0.7469
# Epoch 23/50
# 501/501 [==============================] - 69s 137ms/step - loss: 0.6361 - accuracy: 0.7667 - val_loss: 0.6654 - val_accuracy: 0.7639
# Epoch 24/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.6371 - accuracy: 0.7629 - val_loss: 0.7182 - val_accuracy: 0.7469
# Epoch 25/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.6324 - accuracy: 0.7640 - val_loss: 0.6920 - val_accuracy: 0.7614
# Epoch 26/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.6260 - accuracy: 0.7707 - val_loss: 0.6461 - val_accuracy: 0.7668
# Epoch 27/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.6164 - accuracy: 0.7758 - val_loss: 0.6660 - val_accuracy: 0.7629
# Epoch 28/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.6142 - accuracy: 0.7817 - val_loss: 0.6564 - val_accuracy: 0.7728
# Epoch 29/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.6129 - accuracy: 0.7691 - val_loss: 0.7059 - val_accuracy: 0.7529
# Epoch 30/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.6069 - accuracy: 0.7743 - val_loss: 0.6764 - val_accuracy: 0.7748
# Epoch 31/50
# 501/501 [==============================] - 75s 149ms/step - loss: 0.5969 - accuracy: 0.7813 - val_loss: 0.7068 - val_accuracy: 0.7624
# Epoch 32/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.6014 - accuracy: 0.7747 - val_loss: 0.6931 - val_accuracy: 0.7614
# Epoch 33/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.5894 - accuracy: 0.7808 - val_loss: 0.7784 - val_accuracy: 0.7304
# Epoch 34/50
# 501/501 [==============================] - 68s 136ms/step - loss: 0.5968 - accuracy: 0.7798 - val_loss: 0.6489 - val_accuracy: 0.7624
# Epoch 35/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.5892 - accuracy: 0.7815 - val_loss: 0.7457 - val_accuracy: 0.7364
# Epoch 36/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.5882 - accuracy: 0.7827 - val_loss: 0.6964 - val_accuracy: 0.7614
# Epoch 37/50
# 501/501 [==============================] - 66s 131ms/step - loss: 0.5792 - accuracy: 0.7856 - val_loss: 0.6690 - val_accuracy: 0.7464
# Epoch 38/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.5743 - accuracy: 0.7844 - val_loss: 0.6717 - val_accuracy: 0.7698
# Epoch 39/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.5771 - accuracy: 0.7906 - val_loss: 0.8036 - val_accuracy: 0.7129
# Epoch 40/50
# 501/501 [==============================] - 67s 134ms/step - loss: 0.5630 - accuracy: 0.7892 - val_loss: 0.6475 - val_accuracy: 0.7718
# Epoch 41/50
# 501/501 [==============================] - 66s 133ms/step - loss: 0.5617 - accuracy: 0.7919 - val_loss: 0.6500 - val_accuracy: 0.7718
# Epoch 42/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.5710 - accuracy: 0.7866 - val_loss: 0.7835 - val_accuracy: 0.7149
# Epoch 43/50
# 501/501 [==============================] - 66s 131ms/step - loss: 0.5579 - accuracy: 0.7904 - val_loss: 0.7527 - val_accuracy: 0.7469
# Epoch 44/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.5544 - accuracy: 0.7957 - val_loss: 0.6659 - val_accuracy: 0.7644
# Epoch 45/50
# 501/501 [==============================] - 66s 132ms/step - loss: 0.5501 - accuracy: 0.7988 - val_loss: 0.6399 - val_accuracy: 0.7738
# Epoch 46/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.5415 - accuracy: 0.8000 - val_loss: 0.6298 - val_accuracy: 0.7763
# Epoch 47/50
# 501/501 [==============================] - 67s 133ms/step - loss: 0.5427 - accuracy: 0.8017 - val_loss: 0.9812 - val_accuracy: 0.7019
# Epoch 48/50
# 501/501 [==============================] - 65s 130ms/step - loss: 0.5389 - accuracy: 0.7981 - val_loss: 0.9415 - val_accuracy: 0.6740
# Epoch 49/50
# 501/501 [==============================] - 67s 135ms/step - loss: 0.5384 - accuracy: 0.8027 - val_loss: 0.6316 - val_accuracy: 0.7793
# Epoch 50/50
# 501/501 [==============================] - 68s 135ms/step - loss: 0.5295 - accuracy: 0.8058 - val_loss: 0.6423 - val_accuracy: 0.7723

# %%
loss, acc = model.evaluate(test_gen)
# Out:
# 126/126 [==============================] - 14s 108ms/step - loss: 0.5324 - accuracy: 0.8043

# %%
# model.save("Attempt-3.h5")

# %%
metrics = ["accuracy", "loss"]
for metric in metrics:
    print(metric.upper())
    mt = history.history[metric]
    rng = [x for x in range(1, len(mt)+1)]
    vmt = history.history[v := "val_"+metric]
    plt.plot(rng, mt, label=metric.upper())
    plt.plot(rng, vmt, label=v.upper())
    plt.ylim(*(0, 1) if metric != "loss" else  (0, 5))
    plt.legend()
    plt.show()
# Out:
# ACCURACY
# LOSS
