# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# 0 - akiec
# 1 - bcc
# 2 - bkl
# 3 - df
# 4 - nv
# 5 - vasc
# 6 - mel

# %%
# !mkdir "Data"
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/* /kaggle/working/Data
# !cp -r /kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/* /kaggle/working/Data

# %%
data = pd.read_csv("/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv")
data
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
data = data.drop(["lesion_id", "dx_type", "age", "localization", "sex"], axis=1)
data
# Out:
#            image_id     dx
# 0      ISIC_0027419    bkl
# 1      ISIC_0025030    bkl
# 2      ISIC_0026769    bkl
# 3      ISIC_0025661    bkl
# 4      ISIC_0031633    bkl
# ...             ...    ...
# 10010  ISIC_0033084  akiec
# 10011  ISIC_0033550  akiec
# 10012  ISIC_0033536  akiec
# 10013  ISIC_0032854  akiec
# 10014  ISIC_0032258    mel
#
# [10015 rows x 2 columns]

# %%
data["dx"].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
# data["label"] = [labels[x] for x in data["dx"]]
# data

# %% [markdown]
# # Preprocessing the Images

# %%
dataPath = Path(r"/kaggle/working/Data")
print(len(os.listdir(dataPath)))
# Out:
# 10015

# %%
data["image_id"] = [f"{dataPath}/{x}.jpg" for x in data["image_id"]]
data
# Out:
#                                     image_id     dx
# 0      /kaggle/working/Data/ISIC_0027419.jpg    bkl
# 1      /kaggle/working/Data/ISIC_0025030.jpg    bkl
# 2      /kaggle/working/Data/ISIC_0026769.jpg    bkl
# 3      /kaggle/working/Data/ISIC_0025661.jpg    bkl
# 4      /kaggle/working/Data/ISIC_0031633.jpg    bkl
# ...                                      ...    ...
# 10010  /kaggle/working/Data/ISIC_0033084.jpg  akiec
# 10011  /kaggle/working/Data/ISIC_0033550.jpg  akiec
# 10012  /kaggle/working/Data/ISIC_0033536.jpg  akiec
# 10013  /kaggle/working/Data/ISIC_0032854.jpg  akiec
# 10014  /kaggle/working/Data/ISIC_0032258.jpg    mel
#
# [10015 rows x 2 columns]

# %%
train_data, test_data = train_test_split(data, test_size=.2, stratify=data.dx)
train_data, valid_data = train_test_split(data, test_size=.2, stratify=data.dx)

# %%
train_data.shape, valid_data.shape, test_data.shape
# Out:
# ((8012, 2), (2003, 2), (2003, 2))

# %%
imageDataGenerator = ImageDataGenerator(rescale=1/255.)
train_gen = imageDataGenerator.flow_from_dataframe(train_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
valid_gen = imageDataGenerator.flow_from_dataframe(valid_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
test_gen = imageDataGenerator.flow_from_dataframe(test_data, x_col="image_id", y_col="dx", target_size=[224, 224], mode="categorical", batch_size=16)
# Out:
# Found 8012 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.
# Found 2003 validated image filenames belonging to 7 classes.

# %%
labels = train_gen.class_indices
labels
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
model = Sequential([
    layers.Input(shape=[224, 224, 3], name="Inputs"),
    layers.Conv2D(16, kernel_size=(3, 3), padding="same", activation="relu", name="Conv1"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool1"),
    layers.BatchNormalization(name="BatchNorm1"),
    layers.Conv2D(32, kernel_size=(3, 3), padding="same", activation="relu", name="Conv2"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool2"),
    layers.BatchNormalization(name="BatchNorm2"),
    layers.Conv2D(64, kernel_size=(3, 3), padding="same", activation="relu", name="Conv3"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool3"),
    layers.BatchNormalization(name="BatchNorm3"),
    layers.Conv2D(128, kernel_size=(3, 3), padding="same", activation="relu", name="Conv4"),
    layers.MaxPooling2D(pool_size=2, strides=2, name="maxpool4"),
    layers.BatchNormalization(name="BatchNorm4"),
    layers.Flatten(name="Flatten"),
    layers.Dense(7, activation="softmax", name="Outputs")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1 (Conv2D)              (None, 224, 224, 16)      448
#
#  maxpool1 (MaxPooling2D)     (None, 112, 112, 16)      0
#
#  BatchNorm1 (BatchNormalizat  (None, 112, 112, 16)     64
#  ion)
#
#  Conv2 (Conv2D)              (None, 112, 112, 32)      4640
#
#  maxpool2 (MaxPooling2D)     (None, 56, 56, 32)        0
#
#  BatchNorm2 (BatchNormalizat  (None, 56, 56, 32)       128
#  ion)
#
#  Conv3 (Conv2D)              (None, 56, 56, 64)        18496
#
#  maxpool3 (MaxPooling2D)     (None, 28, 28, 64)        0
#
#  BatchNorm3 (BatchNormalizat  (None, 28, 28, 64)       256
#  ion)
#
#  Conv4 (Conv2D)              (None, 28, 28, 128)       73856
#
#  maxpool4 (MaxPooling2D)     (None, 14, 14, 128)       0
#
#  BatchNorm4 (BatchNormalizat  (None, 14, 14, 128)      512
#  ion)
#
#  Flatten (Flatten)           (None, 25088)             0
#
#  Outputs (Dense)             (None, 7)                 175623
#
# =================================================================
# Total params: 274,023
# Trainable params: 273,543
# Non-trainable params: 480
# _________________________________________________________________

# %%
plot_model(model, show_layer_names=True, show_shapes=True)

# %%
def learningRate(epoch, lr):
    if epoch >= 30:
        return lr * .9
    return lr

learningRateScheduler = LearningRateScheduler(learningRate)

# %%
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=1e-4), metrics=['accuracy'])

# %%
history = model.fit(train_gen, validation_data=valid_gen, epochs=50, callbacks=[learningRateScheduler])
# Out:
# Epoch 1/50
# 501/501 [==============================] - 77s 135ms/step - loss: 1.0341 - accuracy: 0.6764 - val_loss: 1.5619 - val_accuracy: 0.4064 - lr: 1.0000e-04
# Epoch 2/50
# 501/501 [==============================] - 62s 125ms/step - loss: 0.7002 - accuracy: 0.7560 - val_loss: 0.8110 - val_accuracy: 0.7324 - lr: 1.0000e-04
# Epoch 3/50
# 501/501 [==============================] - 62s 123ms/step - loss: 0.5567 - accuracy: 0.7969 - val_loss: 0.8480 - val_accuracy: 0.7399 - lr: 1.0000e-04
# Epoch 4/50
# 501/501 [==============================] - 61s 121ms/step - loss: 0.4204 - accuracy: 0.8517 - val_loss: 0.8773 - val_accuracy: 0.7264 - lr: 1.0000e-04
# Epoch 5/50
# 501/501 [==============================] - 63s 126ms/step - loss: 0.3077 - accuracy: 0.8903 - val_loss: 0.8528 - val_accuracy: 0.7359 - lr: 1.0000e-04
# Epoch 6/50
# 501/501 [==============================] - 65s 130ms/step - loss: 0.2365 - accuracy: 0.9171 - val_loss: 0.8701 - val_accuracy: 0.7454 - lr: 1.0000e-04
# Epoch 7/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.1651 - accuracy: 0.9483 - val_loss: 0.9255 - val_accuracy: 0.7414 - lr: 1.0000e-04
# Epoch 8/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.1115 - accuracy: 0.9695 - val_loss: 0.9186 - val_accuracy: 0.7484 - lr: 1.0000e-04
# Epoch 9/50
# 501/501 [==============================] - 63s 125ms/step - loss: 0.0879 - accuracy: 0.9779 - val_loss: 0.9464 - val_accuracy: 0.7454 - lr: 1.0000e-04
# Epoch 10/50
# 501/501 [==============================] - 63s 126ms/step - loss: 0.0574 - accuracy: 0.9894 - val_loss: 1.0402 - val_accuracy: 0.7374 - lr: 1.0000e-04
# Epoch 11/50
# 501/501 [==============================] - 63s 125ms/step - loss: 0.0477 - accuracy: 0.9904 - val_loss: 1.0199 - val_accuracy: 0.7459 - lr: 1.0000e-04
# Epoch 12/50
# 501/501 [==============================] - 62s 124ms/step - loss: 0.0356 - accuracy: 0.9939 - val_loss: 1.0907 - val_accuracy: 0.7274 - lr: 1.0000e-04
# Epoch 13/50
# 501/501 [==============================] - 62s 123ms/step - loss: 0.0345 - accuracy: 0.9933 - val_loss: 1.1669 - val_accuracy: 0.7324 - lr: 1.0000e-04
# Epoch 14/50
# 501/501 [==============================] - 61s 122ms/step - loss: 0.0265 - accuracy: 0.9958 - val_loss: 1.0551 - val_accuracy: 0.7284 - lr: 1.0000e-04
# Epoch 15/50
# 501/501 [==============================] - 62s 124ms/step - loss: 0.0200 - accuracy: 0.9976 - val_loss: 1.1225 - val_accuracy: 0.7469 - lr: 1.0000e-04
# Epoch 16/50
# 501/501 [==============================] - 63s 125ms/step - loss: 0.0152 - accuracy: 0.9980 - val_loss: 1.4290 - val_accuracy: 0.7044 - lr: 1.0000e-04
# Epoch 17/50
# 501/501 [==============================] - 62s 124ms/step - loss: 0.0462 - accuracy: 0.9860 - val_loss: 1.2575 - val_accuracy: 0.7259 - lr: 1.0000e-04
# Epoch 18/50
# 501/501 [==============================] - 62s 123ms/step - loss: 0.0175 - accuracy: 0.9975 - val_loss: 1.3324 - val_accuracy: 0.7179 - lr: 1.0000e-04
# Epoch 19/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 1.2677 - val_accuracy: 0.7359 - lr: 1.0000e-04
# Epoch 20/50
# 501/501 [==============================] - 62s 125ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 1.3150 - val_accuracy: 0.7429 - lr: 1.0000e-04
# Epoch 21/50
# 501/501 [==============================] - 63s 125ms/step - loss: 0.0042 - accuracy: 0.9999 - val_loss: 1.2287 - val_accuracy: 0.7409 - lr: 1.0000e-04
# Epoch 22/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3013 - val_accuracy: 0.7404 - lr: 1.0000e-04
# Epoch 23/50
# 501/501 [==============================] - 63s 127ms/step - loss: 0.0703 - accuracy: 0.9754 - val_loss: 1.4474 - val_accuracy: 0.7224 - lr: 1.0000e-04
# Epoch 24/50
# 501/501 [==============================] - 64s 128ms/step - loss: 0.0161 - accuracy: 0.9964 - val_loss: 1.4159 - val_accuracy: 0.7339 - lr: 1.0000e-04
# Epoch 25/50
# 501/501 [==============================] - 63s 125ms/step - loss: 0.0042 - accuracy: 0.9999 - val_loss: 1.3078 - val_accuracy: 0.7349 - lr: 1.0000e-04
# Epoch 26/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 1.3393 - val_accuracy: 0.7384 - lr: 1.0000e-04
# Epoch 27/50
# 501/501 [==============================] - 63s 125ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 1.3849 - val_accuracy: 0.7479 - lr: 1.0000e-04
# Epoch 28/50
# 501/501 [==============================] - 62s 124ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 1.8234 - val_accuracy: 0.7114 - lr: 1.0000e-04
# Epoch 29/50
# 501/501 [==============================] - 63s 126ms/step - loss: 0.0482 - accuracy: 0.9829 - val_loss: 1.4642 - val_accuracy: 0.7289 - lr: 1.0000e-04
# Epoch 30/50
# 501/501 [==============================] - 63s 126ms/step - loss: 0.0077 - accuracy: 0.9988 - val_loss: 1.5788 - val_accuracy: 0.7334 - lr: 1.0000e-04
# Epoch 31/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 1.4198 - val_accuracy: 0.7364 - lr: 9.0000e-05
# Epoch 32/50
# 501/501 [==============================] - 64s 127ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 1.4494 - val_accuracy: 0.7354 - lr: 8.1000e-05
# Epoch 33/50
# 501/501 [==============================] - 63s 127ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4775 - val_accuracy: 0.7394 - lr: 7.2900e-05
# Epoch 34/50
# 501/501 [==============================] - 64s 128ms/step - loss: 7.1076e-04 - accuracy: 1.0000 - val_loss: 1.4745 - val_accuracy: 0.7409 - lr: 6.5610e-05
# Epoch 35/50
# 501/501 [==============================] - 63s 126ms/step - loss: 5.4321e-04 - accuracy: 1.0000 - val_loss: 1.4577 - val_accuracy: 0.7399 - lr: 5.9049e-05
# Epoch 36/50
# 501/501 [==============================] - 62s 124ms/step - loss: 5.3495e-04 - accuracy: 1.0000 - val_loss: 1.4790 - val_accuracy: 0.7404 - lr: 5.3144e-05
# Epoch 37/50
# 501/501 [==============================] - 64s 127ms/step - loss: 4.5362e-04 - accuracy: 1.0000 - val_loss: 1.4781 - val_accuracy: 0.7439 - lr: 4.7830e-05
# Epoch 38/50
# 501/501 [==============================] - 63s 125ms/step - loss: 4.4693e-04 - accuracy: 1.0000 - val_loss: 1.4708 - val_accuracy: 0.7449 - lr: 4.3047e-05
# Epoch 39/50
# 501/501 [==============================] - 62s 124ms/step - loss: 3.2693e-04 - accuracy: 1.0000 - val_loss: 1.4740 - val_accuracy: 0.7434 - lr: 3.8742e-05
# Epoch 40/50
# 501/501 [==============================] - 64s 128ms/step - loss: 8.9051e-04 - accuracy: 1.0000 - val_loss: 1.5223 - val_accuracy: 0.7434 - lr: 3.4868e-05
# Epoch 41/50
# 501/501 [==============================] - 63s 127ms/step - loss: 5.0392e-04 - accuracy: 1.0000 - val_loss: 1.5390 - val_accuracy: 0.7454 - lr: 3.1381e-05
# Epoch 42/50
# 501/501 [==============================] - 62s 124ms/step - loss: 2.9226e-04 - accuracy: 1.0000 - val_loss: 1.5155 - val_accuracy: 0.7384 - lr: 2.8243e-05
# Epoch 43/50
# 501/501 [==============================] - 63s 126ms/step - loss: 3.2720e-04 - accuracy: 1.0000 - val_loss: 1.5689 - val_accuracy: 0.7444 - lr: 2.5419e-05
# Epoch 44/50
# 501/501 [==============================] - 62s 124ms/step - loss: 3.2462e-04 - accuracy: 1.0000 - val_loss: 1.5245 - val_accuracy: 0.7454 - lr: 2.2877e-05
# Epoch 45/50
# 501/501 [==============================] - 64s 128ms/step - loss: 4.1380e-04 - accuracy: 1.0000 - val_loss: 1.5281 - val_accuracy: 0.7419 - lr: 2.0589e-05
# Epoch 46/50
# 501/501 [==============================] - 62s 124ms/step - loss: 2.1553e-04 - accuracy: 1.0000 - val_loss: 1.5076 - val_accuracy: 0.7404 - lr: 1.8530e-05
# Epoch 47/50
# 501/501 [==============================] - 63s 126ms/step - loss: 2.4596e-04 - accuracy: 1.0000 - val_loss: 1.5502 - val_accuracy: 0.7424 - lr: 1.6677e-05
# Epoch 48/50
# 501/501 [==============================] - 64s 128ms/step - loss: 1.9579e-04 - accuracy: 1.0000 - val_loss: 1.5291 - val_accuracy: 0.7444 - lr: 1.5009e-05
# Epoch 49/50
# 501/501 [==============================] - 63s 125ms/step - loss: 1.7352e-04 - accuracy: 1.0000 - val_loss: 1.5335 - val_accuracy: 0.7509 - lr: 1.3509e-05
# Epoch 50/50
# 501/501 [==============================] - 63s 125ms/step - loss: 1.3728e-04 - accuracy: 1.0000 - val_loss: 1.5337 - val_accuracy: 0.7469 - lr: 1.2158e-05

# %%
loss, acc = model.evaluate(test_gen)
# Out:
# 126/126 [==============================] - 13s 101ms/step - loss: 0.2893 - accuracy: 0.9506

# %%
# model.save("Attempt-4.h5")

# %%
metrics = ["accuracy", "loss"]
for metric in metrics:
    print(metric.upper())
    mt = history.history[metric]
    rng = [x for x in range(1, len(mt)+1)]
    vmt = history.history[v := "val_"+metric]
    plt.plot(rng, mt, label=metric.upper())
    plt.plot(rng, vmt, label=v.upper())
    plt.ylim(*(0, 1) if metric != "loss" else  (0, 5))
    plt.legend()
    plt.show()
# Out:
# ACCURACY
# LOSS
